# %%
import ollama

prompt = "what is the capital of thailand"

response = ollama.chat(model="llama3.2", messages=[
    # {"role":"system", "content": "You are female. Answer with นะคะ"},
    {"role": "user", "content":prompt}
])

response["message"]["content"]
# Out:
# 'The capital of Thailand is Bangkok.'

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="mydb",
    user="admin",
    password="1234",
    host="localhost",
    port="5432"
)
cur = conn.cursor()
cur.execute("""
    CREATE TABLE IF NOT EXISTS documents (
    id SERIAL PRIMARY KEY,
    content TEXT,
    embedding vector(1024)
    )
""")
conn.commit()
cur.close()
conn.close()

# %%
import os

os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"

from sentence_transformers import SentenceTransformer

embedder = SentenceTransformer("BAAI/bge-m3")

embedding = embedder.encode("คณะครุศาสตร์อุตสาหกรรมและเทคโนโลยี มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง เปิดหลักสูตรปริญญาตรี 4 ภาควิชา").tolist()
embedding
# Out:
# [W728 18:59:34.276050553 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 1025507328 bytes (free: 62259200, total: 6071910400).
# [W728 18:59:34.276297056 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 1025507328 bytes (free: 62259200, total: 6071910400).
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 7
#       3 os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"
#       4
#       5 from sentence_transformers import SentenceTransformer
#       6
# ----> 7 embedder = SentenceTransformer("BAAI/bge-m3")
#       8
#       9 embedding = embedder.encode("คณะครุศาสตร์อุตสาหกรรมและเทคโนโลยี มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง เปิดหลักสูตรปริญญาตรี 4 ภาควิชา").tolist()
#      10 embedding
#
# ...
